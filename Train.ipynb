# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
import numpy as np

seed = 7
np.random.seed(seed)
data = np.loadtxt("data.txt")
X_train = data[:4646,:12]
Y_train = data[:4646,12:13]
X_test = data[4646:6936,:12]
Y_test = data[4646:6936,12:13]
len_y_train = len(Y_train)
len_y_test = len(Y_test)

print(len(Y_train))
print(len(Y_test))

for i in range(0,len_y_train):
    if(Y_train[i]==1000):
        Y_train[i] = 3
        Y_train[i] = int(Y_train[i])
    elif(Y_train[i]==100):
        Y_train[i] = 2
        Y_train[i] = int(Y_train[i])
    elif(Y_train[i]==10):
        Y_train[i] = 1
        Y_train[i] = int(Y_train[i])
    elif(Y_train[i]==1):
        Y_train[i] = 0
        Y_train[i] = int(Y_train[i])

for i in range(0,len_y_test):
    if(Y_test[i]==1000):
        Y_test[i] = 3
        Y_test[i] = int(Y_test[i])
    elif(Y_test[i]==100):
        Y_test[i] = 2
        Y_test[i] = int(Y_test[i])
    elif(Y_test[i]==10):
        Y_test[i] = 1
        Y_test[i] = int(Y_test[i])
    elif(Y_test[i]==1):
        Y_test[i] = 0
        Y_test[i] = int(Y_test[i])

print(Y_train)
print(Y_test)

Y_train = Y_train.astype('int32')
Y_train = np_utils.to_categorical(Y_train,4)
Y_test = Y_test.astype('int32')
Y_test = np_utils.to_categorical(Y_test,4)
model = Sequential()
model.add(Dense(100, input_dim=12, init='uniform', activation='relu'))
model.add(Dense(80, init='uniform', activation='relu'))
model.add(Dense(60, init='uniform', activation='relu'))
model.add(Dense(60, init='uniform', activation='relu'))
model.add(Dense(4))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, Y_train, nb_epoch=150, batch_size=10, verbose=2, validation_data=(X_test,Y_test))
scores = model.evaluate(X_test, Y_test, verbose=0)

print("\n")
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

json_string = model.to_json()
open('model_architecture.json', 'w').write(json_string)
model.save_weights('weights.h5',overwrite=True)
# Out:
# 4646
# 2289
# [[2.]
#  [2.]
#  [2.]
#  ...
#  [3.]
#  [3.]
#  [3.]]
# [[3.]
#  [3.]
#  [3.]
#  ...
#  [2.]
#  [2.]
#  [2.]]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 100)               1300
# _________________________________________________________________
# dense_22 (Dense)             (None, 80)                8080
# _________________________________________________________________
# dense_23 (Dense)             (None, 60)                4860
# _________________________________________________________________
# dense_24 (Dense)             (None, 60)                3660
# _________________________________________________________________
# dense_25 (Dense)             (None, 4)                 244
# _________________________________________________________________
# activation_5 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 18,144
# Trainable params: 18,144
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\nagaraj\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(100, input_dim=12, activation="relu", kernel_initializer="uniform")`
# C:\Users\nagaraj\Anaconda3\lib\site-packages\ipykernel_launcher.py:56: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(80, activation="relu", kernel_initializer="uniform")`
# C:\Users\nagaraj\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(60, activation="relu", kernel_initializer="uniform")`
# C:\Users\nagaraj\Anaconda3\lib\site-packages\ipykernel_launcher.py:58: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(60, activation="relu", kernel_initializer="uniform")`
# C:\Users\nagaraj\Anaconda3\lib\site-packages\ipykernel_launcher.py:63: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 4646 samples, validate on 2289 samples
# Epoch 1/150
#  - 1s - loss: 0.3923 - acc: 0.8329 - val_loss: 0.4051 - val_acc: 0.8187
# Epoch 2/150
#  - 1s - loss: 0.3236 - acc: 0.8662 - val_loss: 0.3343 - val_acc: 0.8559
# Epoch 3/150
#  - 1s - loss: 0.3063 - acc: 0.8704 - val_loss: 0.3337 - val_acc: 0.8559
# Epoch 4/150
#  - 1s - loss: 0.3041 - acc: 0.8744 - val_loss: 0.3901 - val_acc: 0.8321
# Epoch 5/150
#  - 1s - loss: 0.2977 - acc: 0.8754 - val_loss: 0.4185 - val_acc: 0.8362
# Epoch 6/150
#  - 1s - loss: 0.2948 - acc: 0.8776 - val_loss: 0.3344 - val_acc: 0.8573
# Epoch 7/150
#  - 1s - loss: 0.2913 - acc: 0.8789 - val_loss: 0.3146 - val_acc: 0.8681
# Epoch 8/150
#  - 1s - loss: 0.2897 - acc: 0.8781 - val_loss: 0.3362 - val_acc: 0.8546
# Epoch 9/150
#  - 1s - loss: 0.2809 - acc: 0.8814 - val_loss: 0.3476 - val_acc: 0.8609
# Epoch 10/150
#  - 1s - loss: 0.2852 - acc: 0.8814 - val_loss: 0.3031 - val_acc: 0.8719
# Epoch 11/150
#  - 1s - loss: 0.2859 - acc: 0.8817 - val_loss: 0.3108 - val_acc: 0.8717
# Epoch 12/150
#  - 1s - loss: 0.2793 - acc: 0.8849 - val_loss: 0.3085 - val_acc: 0.8664
# Epoch 13/150
#  - 1s - loss: 0.2805 - acc: 0.8828 - val_loss: 0.3178 - val_acc: 0.8648
# Epoch 14/150
#  - 1s - loss: 0.2767 - acc: 0.8839 - val_loss: 0.2984 - val_acc: 0.8727
# Epoch 15/150
#  - 1s - loss: 0.2730 - acc: 0.8864 - val_loss: 0.3101 - val_acc: 0.8661
# Epoch 16/150
#  - 1s - loss: 0.2728 - acc: 0.8867 - val_loss: 0.3219 - val_acc: 0.8675
# Epoch 17/150
#  - 1s - loss: 0.2742 - acc: 0.8840 - val_loss: 0.4110 - val_acc: 0.8451
# Epoch 18/150
#  - 1s - loss: 0.2730 - acc: 0.8851 - val_loss: 0.2975 - val_acc: 0.8710
# Epoch 19/150
#  - 1s - loss: 0.2686 - acc: 0.8880 - val_loss: 0.3059 - val_acc: 0.8733
# Epoch 20/150
#  - 1s - loss: 0.2738 - acc: 0.8854 - val_loss: 0.3354 - val_acc: 0.8592
# Epoch 21/150
#  - 1s - loss: 0.2727 - acc: 0.8862 - val_loss: 0.3609 - val_acc: 0.8505
# Epoch 22/150
#  - 1s - loss: 0.2698 - acc: 0.8873 - val_loss: 0.4192 - val_acc: 0.8398
# Epoch 23/150
#  - 1s - loss: 0.2674 - acc: 0.8872 - val_loss: 0.3603 - val_acc: 0.8457
# Epoch 24/150
#  - 1s - loss: 0.2654 - acc: 0.8883 - val_loss: 0.3354 - val_acc: 0.8629
# Epoch 25/150
#  - 1s - loss: 0.2675 - acc: 0.8866 - val_loss: 0.3163 - val_acc: 0.8706
# Epoch 26/150
#  - 1s - loss: 0.2689 - acc: 0.8868 - val_loss: 0.3286 - val_acc: 0.8664
# Epoch 27/150
#  - 1s - loss: 0.2645 - acc: 0.8893 - val_loss: 0.3360 - val_acc: 0.8602
# Epoch 28/150
#  - 1s - loss: 0.2670 - acc: 0.8864 - val_loss: 0.2915 - val_acc: 0.8736
# Epoch 29/150
#  - 1s - loss: 0.2636 - acc: 0.8891 - val_loss: 0.3202 - val_acc: 0.8748
# Epoch 30/150
#  - 1s - loss: 0.2621 - acc: 0.8883 - val_loss: 0.2957 - val_acc: 0.8712
# Epoch 31/150
#  - 1s - loss: 0.2620 - acc: 0.8909 - val_loss: 0.3047 - val_acc: 0.8658
# Epoch 32/150
#  - 1s - loss: 0.2633 - acc: 0.8883 - val_loss: 0.3102 - val_acc: 0.8639
# Epoch 33/150
#  - 1s - loss: 0.2639 - acc: 0.8885 - val_loss: 0.3420 - val_acc: 0.8571
# Epoch 34/150
#  - 1s - loss: 0.2601 - acc: 0.8899 - val_loss: 0.2992 - val_acc: 0.8705
# Epoch 35/150
#  - 1s - loss: 0.2588 - acc: 0.8919 - val_loss: 0.3131 - val_acc: 0.8684
# Epoch 36/150
#  - 1s - loss: 0.2594 - acc: 0.8893 - val_loss: 0.3135 - val_acc: 0.8678
# Epoch 37/150
#  - 1s - loss: 0.2626 - acc: 0.8896 - val_loss: 0.3051 - val_acc: 0.8713
# Epoch 38/150
#  - 1s - loss: 0.2591 - acc: 0.8889 - val_loss: 0.3106 - val_acc: 0.8717
# Epoch 39/150
#  - 1s - loss: 0.2613 - acc: 0.8910 - val_loss: 0.3005 - val_acc: 0.8742
# Epoch 40/150
#  - 1s - loss: 0.2602 - acc: 0.8906 - val_loss: 0.2989 - val_acc: 0.8729
# Epoch 41/150
#  - 1s - loss: 0.2609 - acc: 0.8900 - val_loss: 0.3035 - val_acc: 0.8729
# Epoch 42/150
#  - 1s - loss: 0.2580 - acc: 0.8910 - val_loss: 0.3003 - val_acc: 0.8709
# Epoch 43/150
#  - 1s - loss: 0.2579 - acc: 0.8925 - val_loss: 0.2971 - val_acc: 0.8720
# Epoch 44/150
#  - 1s - loss: 0.2581 - acc: 0.8901 - val_loss: 0.2922 - val_acc: 0.8751
# Epoch 45/150
#  - 1s - loss: 0.2552 - acc: 0.8939 - val_loss: 0.3026 - val_acc: 0.8705
# Epoch 46/150
#  - 1s - loss: 0.2550 - acc: 0.8915 - val_loss: 0.3144 - val_acc: 0.8663
# Epoch 47/150
#  - 1s - loss: 0.2549 - acc: 0.8911 - val_loss: 0.2897 - val_acc: 0.8742
# Epoch 48/150
#  - 1s - loss: 0.2614 - acc: 0.8904 - val_loss: 0.2907 - val_acc: 0.8745
# Epoch 49/150
#  - 1s - loss: 0.2565 - acc: 0.8921 - val_loss: 0.3243 - val_acc: 0.8577
# Epoch 50/150
#  - 1s - loss: 0.2565 - acc: 0.8916 - val_loss: 0.3086 - val_acc: 0.8693
# Epoch 51/150
#  - 1s - loss: 0.2576 - acc: 0.8895 - val_loss: 0.3201 - val_acc: 0.8652
# Epoch 52/150
#  - 1s - loss: 0.2566 - acc: 0.8935 - val_loss: 0.3162 - val_acc: 0.8658
# Epoch 53/150
#  - 1s - loss: 0.2606 - acc: 0.8902 - val_loss: 0.3140 - val_acc: 0.8715
# Epoch 54/150
#  - 1s - loss: 0.2561 - acc: 0.8915 - val_loss: 0.2952 - val_acc: 0.8778
# Epoch 55/150
#  - 1s - loss: 0.2543 - acc: 0.8916 - val_loss: 0.2921 - val_acc: 0.8748
# Epoch 56/150
#  - 1s - loss: 0.2557 - acc: 0.8912 - val_loss: 0.2967 - val_acc: 0.8729
# Epoch 57/150
#  - 1s - loss: 0.2542 - acc: 0.8920 - val_loss: 0.3275 - val_acc: 0.8708
# Epoch 58/150
#  - 1s - loss: 0.2572 - acc: 0.8911 - val_loss: 0.2982 - val_acc: 0.8705
# Epoch 59/150
#  - 1s - loss: 0.2543 - acc: 0.8919 - val_loss: 0.3149 - val_acc: 0.8724
# Epoch 60/150
#  - 1s - loss: 0.2553 - acc: 0.8916 - val_loss: 0.3045 - val_acc: 0.8724
# Epoch 61/150
#  - 1s - loss: 0.2544 - acc: 0.8926 - val_loss: 0.2977 - val_acc: 0.8688
# Epoch 62/150
#  - 1s - loss: 0.2535 - acc: 0.8917 - val_loss: 0.3061 - val_acc: 0.8733
# Epoch 63/150
#  - 1s - loss: 0.2594 - acc: 0.8913 - val_loss: 0.3060 - val_acc: 0.8727
# Epoch 64/150
#  - 1s - loss: 0.2522 - acc: 0.8925 - val_loss: 0.3232 - val_acc: 0.8646
# Epoch 65/150
#  - 1s - loss: 0.2539 - acc: 0.8915 - val_loss: 0.3114 - val_acc: 0.8706
# Epoch 66/150
#  - 1s - loss: 0.2545 - acc: 0.8940 - val_loss: 0.3035 - val_acc: 0.8753
# Epoch 67/150
#  - 1s - loss: 0.2525 - acc: 0.8910 - val_loss: 0.3208 - val_acc: 0.8722
# Epoch 68/150
#  - 1s - loss: 0.2521 - acc: 0.8925 - val_loss: 0.3177 - val_acc: 0.8720
# Epoch 69/150
#  - 1s - loss: 0.2554 - acc: 0.8923 - val_loss: 0.3080 - val_acc: 0.8669
# Epoch 70/150
#  - 1s - loss: 0.2502 - acc: 0.8944 - val_loss: 0.3091 - val_acc: 0.8752
# Epoch 71/150
#  - 1s - loss: 0.2527 - acc: 0.8929 - val_loss: 0.3014 - val_acc: 0.8740
# Epoch 72/150
#  - 1s - loss: 0.2508 - acc: 0.8943 - val_loss: 0.3130 - val_acc: 0.8729
# Epoch 73/150
#  - 1s - loss: 0.2540 - acc: 0.8926 - val_loss: 0.2941 - val_acc: 0.8736
# Epoch 74/150
#  - 1s - loss: 0.2519 - acc: 0.8954 - val_loss: 0.2906 - val_acc: 0.8742
# Epoch 75/150
#  - 1s - loss: 0.2519 - acc: 0.8928 - val_loss: 0.3089 - val_acc: 0.8711
# Epoch 76/150
#  - 1s - loss: 0.2535 - acc: 0.8931 - val_loss: 0.3061 - val_acc: 0.8730
# Epoch 77/150
#  - 1s - loss: 0.2496 - acc: 0.8945 - val_loss: 0.3069 - val_acc: 0.8742
# Epoch 78/150
#  - 1s - loss: 0.2542 - acc: 0.8925 - val_loss: 0.3261 - val_acc: 0.8698
# Epoch 79/150
#  - 1s - loss: 0.2523 - acc: 0.8939 - val_loss: 0.3049 - val_acc: 0.8771
# Epoch 80/150
#  - 1s - loss: 0.2512 - acc: 0.8933 - val_loss: 0.3670 - val_acc: 0.8682
# Epoch 81/150
#  - 1s - loss: 0.2535 - acc: 0.8920 - val_loss: 0.3002 - val_acc: 0.8705
# Epoch 82/150
#  - 1s - loss: 0.2568 - acc: 0.8920 - val_loss: 0.3139 - val_acc: 0.8595
# Epoch 83/150
#  - 1s - loss: 0.2564 - acc: 0.8923 - val_loss: 0.3044 - val_acc: 0.8710
# Epoch 84/150
#  - 1s - loss: 0.2489 - acc: 0.8953 - val_loss: 0.2993 - val_acc: 0.8723
# Epoch 85/150
#  - 1s - loss: 0.2485 - acc: 0.8930 - val_loss: 0.3067 - val_acc: 0.8626
# Epoch 86/150
#  - 1s - loss: 0.2503 - acc: 0.8943 - val_loss: 0.3033 - val_acc: 0.8705
# Epoch 87/150
#  - 1s - loss: 0.2530 - acc: 0.8967 - val_loss: 0.3045 - val_acc: 0.8709
# Epoch 88/150
#  - 1s - loss: 0.2525 - acc: 0.8924 - val_loss: 0.2909 - val_acc: 0.8730
# Epoch 89/150
#  - 1s - loss: 0.2544 - acc: 0.8926 - val_loss: 0.2902 - val_acc: 0.8742
# Epoch 90/150
#  - 1s - loss: 0.2503 - acc: 0.8932 - val_loss: 0.3037 - val_acc: 0.8755
# Epoch 91/150
#  - 1s - loss: 0.2508 - acc: 0.8942 - val_loss: 0.2955 - val_acc: 0.8777
# Epoch 92/150
#  - 1s - loss: 0.2499 - acc: 0.8943 - val_loss: 0.3016 - val_acc: 0.8775
# Epoch 93/150
#  - 1s - loss: 0.2498 - acc: 0.8958 - val_loss: 0.3040 - val_acc: 0.8737
# Epoch 94/150
#  - 1s - loss: 0.2506 - acc: 0.8945 - val_loss: 0.2942 - val_acc: 0.8754
# Epoch 95/150
#  - 1s - loss: 0.2502 - acc: 0.8945 - val_loss: 0.2996 - val_acc: 0.8711
# Epoch 96/150
#  - 1s - loss: 0.2502 - acc: 0.8943 - val_loss: 0.2917 - val_acc: 0.8746
# Epoch 97/150
#  - 1s - loss: 0.2477 - acc: 0.8955 - val_loss: 0.2951 - val_acc: 0.8740
# Epoch 98/150
#  - 1s - loss: 0.2540 - acc: 0.8935 - val_loss: 0.2955 - val_acc: 0.8725
# Epoch 99/150
#  - 1s - loss: 0.2520 - acc: 0.8928 - val_loss: 0.3001 - val_acc: 0.8675
# Epoch 100/150
#  - 1s - loss: 0.2474 - acc: 0.8959 - val_loss: 0.3134 - val_acc: 0.8688
# Epoch 101/150
#  - 1s - loss: 0.2540 - acc: 0.8959 - val_loss: 0.3268 - val_acc: 0.8711
# Epoch 102/150
#  - 1s - loss: 0.2507 - acc: 0.8930 - val_loss: 0.3204 - val_acc: 0.8723
# Epoch 103/150
#  - 1s - loss: 0.2493 - acc: 0.8952 - val_loss: 0.3082 - val_acc: 0.8634
# Epoch 104/150
#  - 1s - loss: 0.2500 - acc: 0.8949 - val_loss: 0.3006 - val_acc: 0.8751
# Epoch 105/150
#  - 1s - loss: 0.2477 - acc: 0.8952 - val_loss: 0.3143 - val_acc: 0.8693
# Epoch 106/150
#  - 1s - loss: 0.2522 - acc: 0.8945 - val_loss: 0.3443 - val_acc: 0.8641
# Epoch 107/150
#  - 1s - loss: 0.2483 - acc: 0.8945 - val_loss: 0.3231 - val_acc: 0.8683
# Epoch 108/150
#  - 1s - loss: 0.2556 - acc: 0.8904 - val_loss: 0.2998 - val_acc: 0.8754
# Epoch 109/150
#  - 1s - loss: 0.2509 - acc: 0.8932 - val_loss: 0.3233 - val_acc: 0.8638
# Epoch 110/150
#  - 1s - loss: 0.2476 - acc: 0.8951 - val_loss: 0.2868 - val_acc: 0.8717
# Epoch 111/150
#  - 1s - loss: 0.2499 - acc: 0.8957 - val_loss: 0.3121 - val_acc: 0.8701
# Epoch 112/150
#  - 1s - loss: 0.2478 - acc: 0.8942 - val_loss: 0.3165 - val_acc: 0.8687
# Epoch 113/150
#  - 1s - loss: 0.2486 - acc: 0.8960 - val_loss: 0.3063 - val_acc: 0.8704
# Epoch 114/150
#  - 1s - loss: 0.2518 - acc: 0.8942 - val_loss: 0.3410 - val_acc: 0.8715
# Epoch 115/150
#  - 1s - loss: 0.2498 - acc: 0.8940 - val_loss: 0.3099 - val_acc: 0.8741
# Epoch 116/150
#  - 1s - loss: 0.2499 - acc: 0.8937 - val_loss: 0.3192 - val_acc: 0.8787
# Epoch 117/150
#  - 1s - loss: 0.2467 - acc: 0.8936 - val_loss: 0.3129 - val_acc: 0.8641
# Epoch 118/150
#  - 1s - loss: 0.2484 - acc: 0.8947 - val_loss: 0.2955 - val_acc: 0.8712
# Epoch 119/150
#  - 1s - loss: 0.2460 - acc: 0.8958 - val_loss: 0.3095 - val_acc: 0.8725
# Epoch 120/150
#  - 1s - loss: 0.2494 - acc: 0.8935 - val_loss: 0.2972 - val_acc: 0.8745
# Epoch 121/150
#  - 1s - loss: 0.2475 - acc: 0.8947 - val_loss: 0.2908 - val_acc: 0.8720
# Epoch 122/150
#  - 1s - loss: 0.2488 - acc: 0.8960 - val_loss: 0.3418 - val_acc: 0.8683
# Epoch 123/150
#  - 1s - loss: 0.2489 - acc: 0.8957 - val_loss: 0.2892 - val_acc: 0.8779
# Epoch 124/150
#  - 1s - loss: 0.2483 - acc: 0.8937 - val_loss: 0.2965 - val_acc: 0.8771
# Epoch 125/150
#  - 1s - loss: 0.2458 - acc: 0.8947 - val_loss: 0.3057 - val_acc: 0.8717
# Epoch 126/150
#  - 1s - loss: 0.2491 - acc: 0.8940 - val_loss: 0.3073 - val_acc: 0.8704
# Epoch 127/150
#  - 1s - loss: 0.2457 - acc: 0.8949 - val_loss: 0.3362 - val_acc: 0.8573
# Epoch 128/150
#  - 1s - loss: 0.2465 - acc: 0.8964 - val_loss: 0.3109 - val_acc: 0.8712
# Epoch 129/150
#  - 1s - loss: 0.2469 - acc: 0.8969 - val_loss: 0.2948 - val_acc: 0.8725
# Epoch 130/150
#  - 1s - loss: 0.2484 - acc: 0.8964 - val_loss: 0.2999 - val_acc: 0.8742
# Epoch 131/150
#  - 1s - loss: 0.2469 - acc: 0.8950 - val_loss: 0.2985 - val_acc: 0.8772
# Epoch 132/150
#  - 1s - loss: 0.2429 - acc: 0.8968 - val_loss: 0.3089 - val_acc: 0.8741
# Epoch 133/150
#  - 1s - loss: 0.2475 - acc: 0.8958 - val_loss: 0.3083 - val_acc: 0.8700
# Epoch 134/150
#  - 1s - loss: 0.2452 - acc: 0.8958 - val_loss: 0.2981 - val_acc: 0.8712
# Epoch 135/150
#  - 1s - loss: 0.2473 - acc: 0.8951 - val_loss: 0.3175 - val_acc: 0.8677
# Epoch 136/150
#  - 1s - loss: 0.2489 - acc: 0.8931 - val_loss: 0.3165 - val_acc: 0.8717
# Epoch 137/150
#  - 1s - loss: 0.2463 - acc: 0.8924 - val_loss: 0.2979 - val_acc: 0.8661
# Epoch 138/150
#  - 1s - loss: 0.2466 - acc: 0.8956 - val_loss: 0.2980 - val_acc: 0.8744
# Epoch 139/150
#  - 1s - loss: 0.2473 - acc: 0.8947 - val_loss: 0.3161 - val_acc: 0.8659
# Epoch 140/150
#  - 1s - loss: 0.2458 - acc: 0.8963 - val_loss: 0.3127 - val_acc: 0.8592
# Epoch 141/150
#  - 1s - loss: 0.2450 - acc: 0.8964 - val_loss: 0.3015 - val_acc: 0.8705
# Epoch 142/150
#  - 1s - loss: 0.2487 - acc: 0.8957 - val_loss: 0.2956 - val_acc: 0.8720
# Epoch 143/150
#  - 1s - loss: 0.2449 - acc: 0.8963 - val_loss: 0.2961 - val_acc: 0.8715
# Epoch 144/150
#  - 1s - loss: 0.2472 - acc: 0.8926 - val_loss: 0.3068 - val_acc: 0.8681
# Epoch 145/150
#  - 1s - loss: 0.2457 - acc: 0.8953 - val_loss: 0.2961 - val_acc: 0.8759
# Epoch 146/150
#  - 1s - loss: 0.2449 - acc: 0.8980 - val_loss: 0.3172 - val_acc: 0.8662
# Epoch 147/150
#  - 1s - loss: 0.2449 - acc: 0.8967 - val_loss: 0.3192 - val_acc: 0.8711
# Epoch 148/150
#  - 1s - loss: 0.2452 - acc: 0.8956 - val_loss: 0.3032 - val_acc: 0.8727
# Epoch 149/150
#  - 1s - loss: 0.2443 - acc: 0.8957 - val_loss: 0.2959 - val_acc: 0.8658
# Epoch 150/150
#  - 1s - loss: 0.2456 - acc: 0.8972 - val_loss: 0.3343 - val_acc: 0.8652
#
#
# acc: 86.52%
