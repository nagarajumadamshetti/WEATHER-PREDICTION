# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
import numpy as np

seed = 7
np.random.seed(seed)
data = np.loadtxt("data.txt")
X_train = data[:4646,:12]
Y_train = data[:4646,12:13]
X_test = data[4646:6936,:12]
Y_test = data[4646:6936,12:13]
len_y_train = len(Y_train)
len_y_test = len(Y_test)

print(len(Y_train))
print(len(Y_test))

for i in range(0,len_y_train):
    if(Y_train[i]==1000):
        Y_train[i] = 3
        Y_train[i] = int(Y_train[i])
    elif(Y_train[i]==100):
        Y_train[i] = 2
        Y_train[i] = int(Y_train[i])
    elif(Y_train[i]==10):
        Y_train[i] = 1
        Y_train[i] = int(Y_train[i])
    elif(Y_train[i]==1):
        Y_train[i] = 0
        Y_train[i] = int(Y_train[i])

for i in range(0,len_y_test):
    if(Y_test[i]==1000):
        Y_test[i] = 3
        Y_test[i] = int(Y_test[i])
    elif(Y_test[i]==100):
        Y_test[i] = 2
        Y_test[i] = int(Y_test[i])
    elif(Y_test[i]==10):
        Y_test[i] = 1
        Y_test[i] = int(Y_test[i])
    elif(Y_test[i]==1):
        Y_test[i] = 0
        Y_test[i] = int(Y_test[i])

print(Y_train)
print(Y_test)

Y_train = Y_train.astype('int32')
Y_train = np_utils.to_categorical(Y_train,4)
Y_test = Y_test.astype('int32')
Y_test = np_utils.to_categorical(Y_test,4)
model = Sequential()
model.add(Dense(100, input_dim=12, init='uniform', activation='relu'))
model.add(Dense(80, init='uniform', activation='relu'))
model.add(Dense(60, init='uniform', activation='relu'))
model.add(Dense(60, init='uniform', activation='relu'))
model.add(Dense(4))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, Y_train, nb_epoch=150, batch_size=10, verbose=2, validation_data=(X_test,Y_test))
scores = model.evaluate(X_test, Y_test, verbose=0)

print("\n")
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

json_string = model.to_json()
open('model_architecture.json', 'w').write(json_string)
model.save_weights('weights.h5',overwrite=True)
# Out:
# C:\Users\nagaraj\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 4646
# 2289
# [[2.]
#  [2.]
#  [2.]
#  ...
#  [3.]
#  [3.]
#  [3.]]
# [[3.]
#  [3.]
#  [3.]
#  ...
#  [2.]
#  [2.]
#  [2.]]
# C:\Users\nagaraj\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(100, input_dim=12, activation="relu", kernel_initializer="uniform")`
# C:\Users\nagaraj\Anaconda3\lib\site-packages\ipykernel_launcher.py:56: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(80, activation="relu", kernel_initializer="uniform")`
# C:\Users\nagaraj\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(60, activation="relu", kernel_initializer="uniform")`
# C:\Users\nagaraj\Anaconda3\lib\site-packages\ipykernel_launcher.py:58: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(60, activation="relu", kernel_initializer="uniform")`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 100)               1300
# _________________________________________________________________
# dense_2 (Dense)              (None, 80)                8080
# _________________________________________________________________
# dense_3 (Dense)              (None, 60)                4860
# _________________________________________________________________
# dense_4 (Dense)              (None, 60)                3660
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 244
# _________________________________________________________________
# activation_1 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 18,144
# Trainable params: 18,144
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\nagaraj\Anaconda3\lib\site-packages\ipykernel_launcher.py:63: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 4646 samples, validate on 2289 samples
# Epoch 1/150
#  - 3s - loss: 0.3981 - acc: 0.8307 - val_loss: 0.4182 - val_acc: 0.8092
# Epoch 2/150
#  - 1s - loss: 0.3256 - acc: 0.8679 - val_loss: 0.3439 - val_acc: 0.8577
# Epoch 3/150
#  - 1s - loss: 0.3079 - acc: 0.8714 - val_loss: 0.3342 - val_acc: 0.8561
# Epoch 4/150
#  - 1s - loss: 0.3065 - acc: 0.8735 - val_loss: 0.3546 - val_acc: 0.8473
# Epoch 5/150
#  - 1s - loss: 0.2979 - acc: 0.8747 - val_loss: 0.4342 - val_acc: 0.8331
# Epoch 6/150
#  - 1s - loss: 0.2935 - acc: 0.8776 - val_loss: 0.3328 - val_acc: 0.8567
# Epoch 7/150
#  - 1s - loss: 0.2922 - acc: 0.8768 - val_loss: 0.3353 - val_acc: 0.8598
# Epoch 8/150
#  - 1s - loss: 0.2898 - acc: 0.8777 - val_loss: 0.3451 - val_acc: 0.8499
# Epoch 9/150
#  - 1s - loss: 0.2830 - acc: 0.8809 - val_loss: 0.3490 - val_acc: 0.8582
# Epoch 10/150
#  - 1s - loss: 0.2852 - acc: 0.8813 - val_loss: 0.3093 - val_acc: 0.8695
# Epoch 11/150
#  - 1s - loss: 0.2848 - acc: 0.8820 - val_loss: 0.3186 - val_acc: 0.8721
# Epoch 12/150
#  - 1s - loss: 0.2791 - acc: 0.8844 - val_loss: 0.3048 - val_acc: 0.8673
# Epoch 13/150
#  - 1s - loss: 0.2793 - acc: 0.8827 - val_loss: 0.3328 - val_acc: 0.8517
# Epoch 14/150
#  - 1s - loss: 0.2775 - acc: 0.8837 - val_loss: 0.3062 - val_acc: 0.8708
# Epoch 15/150
#  - 1s - loss: 0.2730 - acc: 0.8859 - val_loss: 0.3139 - val_acc: 0.8656
# Epoch 16/150
#  - 1s - loss: 0.2748 - acc: 0.8864 - val_loss: 0.3296 - val_acc: 0.8700
# Epoch 17/150
#  - 1s - loss: 0.2733 - acc: 0.8855 - val_loss: 0.3494 - val_acc: 0.8558
# Epoch 18/150
#  - 1s - loss: 0.2716 - acc: 0.8853 - val_loss: 0.2995 - val_acc: 0.8708
# Epoch 19/150
#  - 1s - loss: 0.2693 - acc: 0.8889 - val_loss: 0.3025 - val_acc: 0.8740
# Epoch 20/150
#  - 1s - loss: 0.2755 - acc: 0.8868 - val_loss: 0.3372 - val_acc: 0.8565
# Epoch 21/150
#  - 1s - loss: 0.2722 - acc: 0.8853 - val_loss: 0.3224 - val_acc: 0.8644
# Epoch 22/150
#  - 1s - loss: 0.2698 - acc: 0.8874 - val_loss: 0.4251 - val_acc: 0.8440
# Epoch 23/150
#  - 1s - loss: 0.2697 - acc: 0.8868 - val_loss: 0.3626 - val_acc: 0.8495
# Epoch 24/150
#  - 1s - loss: 0.2665 - acc: 0.8875 - val_loss: 0.3359 - val_acc: 0.8610
# Epoch 25/150
#  - 1s - loss: 0.2694 - acc: 0.8864 - val_loss: 0.2983 - val_acc: 0.8734
# Epoch 26/150
#  - 1s - loss: 0.2681 - acc: 0.8887 - val_loss: 0.3150 - val_acc: 0.8713
# Epoch 27/150
#  - 1s - loss: 0.2651 - acc: 0.8899 - val_loss: 0.3528 - val_acc: 0.8528
# Epoch 28/150
#  - 1s - loss: 0.2696 - acc: 0.8862 - val_loss: 0.2925 - val_acc: 0.8728
# Epoch 29/150
#  - 1s - loss: 0.2655 - acc: 0.8903 - val_loss: 0.3152 - val_acc: 0.8721
# Epoch 30/150
#  - 1s - loss: 0.2622 - acc: 0.8888 - val_loss: 0.2958 - val_acc: 0.8739
# Epoch 31/150
#  - 1s - loss: 0.2652 - acc: 0.8891 - val_loss: 0.2955 - val_acc: 0.8702
# Epoch 32/150
#  - 1s - loss: 0.2648 - acc: 0.8883 - val_loss: 0.3201 - val_acc: 0.8597
# Epoch 33/150
#  - 1s - loss: 0.2650 - acc: 0.8879 - val_loss: 0.3303 - val_acc: 0.8611
# Epoch 34/150
#  - 1s - loss: 0.2621 - acc: 0.8914 - val_loss: 0.3062 - val_acc: 0.8731
# Epoch 35/150
#  - 1s - loss: 0.2607 - acc: 0.8902 - val_loss: 0.3042 - val_acc: 0.8695
# Epoch 36/150
#  - 1s - loss: 0.2574 - acc: 0.8897 - val_loss: 0.2938 - val_acc: 0.8698
# Epoch 37/150
#  - 1s - loss: 0.2652 - acc: 0.8879 - val_loss: 0.3001 - val_acc: 0.8753
# Epoch 38/150
#  - 1s - loss: 0.2614 - acc: 0.8883 - val_loss: 0.3040 - val_acc: 0.8744
# Epoch 39/150
#  - 1s - loss: 0.2610 - acc: 0.8920 - val_loss: 0.3107 - val_acc: 0.8710
# Epoch 40/150
#  - 1s - loss: 0.2605 - acc: 0.8893 - val_loss: 0.2965 - val_acc: 0.8742
# Epoch 41/150
#  - 1s - loss: 0.2614 - acc: 0.8888 - val_loss: 0.3042 - val_acc: 0.8754
# Epoch 42/150
#  - 1s - loss: 0.2597 - acc: 0.8917 - val_loss: 0.3040 - val_acc: 0.8707
# Epoch 43/150
#  - 1s - loss: 0.2590 - acc: 0.8914 - val_loss: 0.3039 - val_acc: 0.8702
# Epoch 44/150
#  - 1s - loss: 0.2580 - acc: 0.8917 - val_loss: 0.2972 - val_acc: 0.8732
# Epoch 45/150
#  - 1s - loss: 0.2554 - acc: 0.8916 - val_loss: 0.2887 - val_acc: 0.8751
# Epoch 46/150
#  - 1s - loss: 0.2575 - acc: 0.8895 - val_loss: 0.3155 - val_acc: 0.8675
# Epoch 47/150
#  - 1s - loss: 0.2567 - acc: 0.8913 - val_loss: 0.2926 - val_acc: 0.8732
# Epoch 48/150
#  - 1s - loss: 0.2626 - acc: 0.8899 - val_loss: 0.2892 - val_acc: 0.8752
# Epoch 49/150
#  - 1s - loss: 0.2569 - acc: 0.8923 - val_loss: 0.3513 - val_acc: 0.8409
# Epoch 50/150
#  - 1s - loss: 0.2591 - acc: 0.8920 - val_loss: 0.2940 - val_acc: 0.8741
# Epoch 51/150
#  - 1s - loss: 0.2579 - acc: 0.8912 - val_loss: 0.2970 - val_acc: 0.8658
# Epoch 52/150
#  - 1s - loss: 0.2576 - acc: 0.8915 - val_loss: 0.3371 - val_acc: 0.8568
# Epoch 53/150
#  - 1s - loss: 0.2594 - acc: 0.8911 - val_loss: 0.2981 - val_acc: 0.8772
# Epoch 54/150
#  - 1s - loss: 0.2563 - acc: 0.8941 - val_loss: 0.3262 - val_acc: 0.8673
# Epoch 55/150
#  - 1s - loss: 0.2545 - acc: 0.8920 - val_loss: 0.2882 - val_acc: 0.8746
# Epoch 56/150
#  - 1s - loss: 0.2563 - acc: 0.8915 - val_loss: 0.2965 - val_acc: 0.8719
# Epoch 57/150
#  - 1s - loss: 0.2531 - acc: 0.8923 - val_loss: 0.3441 - val_acc: 0.8657
# Epoch 58/150
#  - 1s - loss: 0.2564 - acc: 0.8921 - val_loss: 0.2932 - val_acc: 0.8685
# Epoch 59/150
#  - 1s - loss: 0.2550 - acc: 0.8909 - val_loss: 0.3277 - val_acc: 0.8644
# Epoch 60/150
#  - 1s - loss: 0.2569 - acc: 0.8917 - val_loss: 0.3138 - val_acc: 0.8675
# Epoch 61/150
#  - 1s - loss: 0.2537 - acc: 0.8924 - val_loss: 0.2978 - val_acc: 0.8680
# Epoch 62/150
#  - 1s - loss: 0.2524 - acc: 0.8909 - val_loss: 0.2954 - val_acc: 0.8745
# Epoch 63/150
#  - 1s - loss: 0.2580 - acc: 0.8903 - val_loss: 0.3064 - val_acc: 0.8737
# Epoch 64/150
#  - 1s - loss: 0.2555 - acc: 0.8910 - val_loss: 0.3169 - val_acc: 0.8626
# Epoch 65/150
#  - 1s - loss: 0.2535 - acc: 0.8915 - val_loss: 0.3177 - val_acc: 0.8745
# Epoch 66/150
#  - 1s - loss: 0.2519 - acc: 0.8936 - val_loss: 0.3034 - val_acc: 0.8734
# Epoch 67/150
#  - 1s - loss: 0.2531 - acc: 0.8924 - val_loss: 0.3387 - val_acc: 0.8666
# Epoch 68/150
#  - 1s - loss: 0.2548 - acc: 0.8913 - val_loss: 0.2968 - val_acc: 0.8733
# Epoch 69/150
#  - 1s - loss: 0.2531 - acc: 0.8924 - val_loss: 0.2980 - val_acc: 0.8670
# Epoch 70/150
#  - 1s - loss: 0.2518 - acc: 0.8924 - val_loss: 0.2989 - val_acc: 0.8752
# Epoch 71/150
#  - 1s - loss: 0.2538 - acc: 0.8923 - val_loss: 0.3009 - val_acc: 0.8718
# Epoch 72/150
#  - 1s - loss: 0.2507 - acc: 0.8939 - val_loss: 0.3092 - val_acc: 0.8671
# Epoch 73/150
#  - 1s - loss: 0.2546 - acc: 0.8917 - val_loss: 0.2896 - val_acc: 0.8700
# Epoch 74/150
#  - 1s - loss: 0.2522 - acc: 0.8929 - val_loss: 0.2927 - val_acc: 0.8751
# Epoch 75/150
#  - 1s - loss: 0.2518 - acc: 0.8926 - val_loss: 0.2982 - val_acc: 0.8685
# Epoch 76/150
#  - 1s - loss: 0.2547 - acc: 0.8933 - val_loss: 0.2985 - val_acc: 0.8730
# Epoch 77/150
#  - 1s - loss: 0.2525 - acc: 0.8933 - val_loss: 0.2965 - val_acc: 0.8771
# Epoch 78/150
#  - 1s - loss: 0.2539 - acc: 0.8917 - val_loss: 0.3241 - val_acc: 0.8678
# Epoch 79/150
#  - 1s - loss: 0.2527 - acc: 0.8939 - val_loss: 0.3060 - val_acc: 0.8747
# Epoch 80/150
#  - 1s - loss: 0.2513 - acc: 0.8938 - val_loss: 0.3388 - val_acc: 0.8634
# Epoch 81/150
#  - 1s - loss: 0.2547 - acc: 0.8925 - val_loss: 0.2899 - val_acc: 0.8731
# Epoch 82/150
#  - 1s - loss: 0.2518 - acc: 0.8936 - val_loss: 0.3415 - val_acc: 0.8426
# Epoch 83/150
#  - 1s - loss: 0.2566 - acc: 0.8913 - val_loss: 0.3007 - val_acc: 0.8711
# Epoch 84/150
#  - 1s - loss: 0.2498 - acc: 0.8947 - val_loss: 0.2900 - val_acc: 0.8736
# Epoch 85/150
#  - 1s - loss: 0.2488 - acc: 0.8944 - val_loss: 0.2892 - val_acc: 0.8700
# Epoch 86/150
#  - 1s - loss: 0.2522 - acc: 0.8936 - val_loss: 0.2934 - val_acc: 0.8717
# Epoch 87/150
#  - 1s - loss: 0.2556 - acc: 0.8932 - val_loss: 0.2979 - val_acc: 0.8736
# Epoch 88/150
#  - 1s - loss: 0.2525 - acc: 0.8927 - val_loss: 0.2954 - val_acc: 0.8740
# Epoch 89/150
#  - 1s - loss: 0.2524 - acc: 0.8949 - val_loss: 0.2905 - val_acc: 0.8746
# Epoch 90/150
#  - 1s - loss: 0.2529 - acc: 0.8921 - val_loss: 0.3103 - val_acc: 0.8615
# Epoch 91/150
#  - 1s - loss: 0.2531 - acc: 0.8932 - val_loss: 0.2939 - val_acc: 0.8733
# Epoch 92/150
#  - 1s - loss: 0.2497 - acc: 0.8943 - val_loss: 0.2931 - val_acc: 0.8736
# Epoch 93/150
#  - 1s - loss: 0.2513 - acc: 0.8955 - val_loss: 0.2885 - val_acc: 0.8765
# Epoch 94/150
#  - 1s - loss: 0.2521 - acc: 0.8933 - val_loss: 0.2838 - val_acc: 0.8744
# Epoch 95/150
#  - 1s - loss: 0.2528 - acc: 0.8941 - val_loss: 0.2971 - val_acc: 0.8697
# Epoch 96/150
#  - 1s - loss: 0.2491 - acc: 0.8951 - val_loss: 0.2878 - val_acc: 0.8748
# Epoch 97/150
#  - 1s - loss: 0.2484 - acc: 0.8951 - val_loss: 0.2960 - val_acc: 0.8724
# Epoch 98/150
#  - 1s - loss: 0.2533 - acc: 0.8921 - val_loss: 0.2953 - val_acc: 0.8720
# Epoch 99/150
#  - 1s - loss: 0.2533 - acc: 0.8932 - val_loss: 0.2962 - val_acc: 0.8671
# Epoch 100/150
#  - 1s - loss: 0.2497 - acc: 0.8952 - val_loss: 0.2947 - val_acc: 0.8727
# Epoch 101/150
#  - 1s - loss: 0.2522 - acc: 0.8928 - val_loss: 0.3028 - val_acc: 0.8713
# Epoch 102/150
#  - 1s - loss: 0.2487 - acc: 0.8951 - val_loss: 0.3022 - val_acc: 0.8779
# Epoch 103/150
#  - 1s - loss: 0.2502 - acc: 0.8945 - val_loss: 0.3081 - val_acc: 0.8709
# Epoch 104/150
#  - 1s - loss: 0.2494 - acc: 0.8940 - val_loss: 0.2935 - val_acc: 0.8755
# Epoch 105/150
#  - 1s - loss: 0.2481 - acc: 0.8957 - val_loss: 0.2881 - val_acc: 0.8723
# Epoch 106/150
#  - 1s - loss: 0.2512 - acc: 0.8927 - val_loss: 0.3517 - val_acc: 0.8579
# Epoch 107/150
#  - 1s - loss: 0.2508 - acc: 0.8943 - val_loss: 0.3103 - val_acc: 0.8710
# Epoch 108/150
#  - 1s - loss: 0.2514 - acc: 0.8929 - val_loss: 0.3036 - val_acc: 0.8744
# Epoch 109/150
#  - 1s - loss: 0.2519 - acc: 0.8929 - val_loss: 0.2952 - val_acc: 0.8692
# Epoch 110/150
#  - 1s - loss: 0.2479 - acc: 0.8931 - val_loss: 0.2862 - val_acc: 0.8723
# Epoch 111/150
#  - 1s - loss: 0.2499 - acc: 0.8942 - val_loss: 0.3121 - val_acc: 0.8752
# Epoch 112/150
#  - 1s - loss: 0.2498 - acc: 0.8944 - val_loss: 0.3047 - val_acc: 0.8669
# Epoch 113/150
#  - 1s - loss: 0.2487 - acc: 0.8937 - val_loss: 0.3023 - val_acc: 0.8716
# Epoch 114/150
#  - 1s - loss: 0.2497 - acc: 0.8942 - val_loss: 0.3098 - val_acc: 0.8728
# Epoch 115/150
#  - 1s - loss: 0.2504 - acc: 0.8934 - val_loss: 0.3031 - val_acc: 0.8717
# Epoch 116/150
#  - 1s - loss: 0.2489 - acc: 0.8950 - val_loss: 0.3263 - val_acc: 0.8720
# Epoch 117/150
#  - 1s - loss: 0.2490 - acc: 0.8938 - val_loss: 0.3128 - val_acc: 0.8660
# Epoch 118/150
#  - 1s - loss: 0.2497 - acc: 0.8941 - val_loss: 0.2935 - val_acc: 0.8734
# Epoch 119/150
#  - 1s - loss: 0.2485 - acc: 0.8959 - val_loss: 0.3143 - val_acc: 0.8708
# Epoch 120/150
#  - 1s - loss: 0.2495 - acc: 0.8952 - val_loss: 0.3091 - val_acc: 0.8764
# Epoch 121/150
#  - 1s - loss: 0.2512 - acc: 0.8923 - val_loss: 0.2881 - val_acc: 0.8716
# Epoch 122/150
#  - 1s - loss: 0.2513 - acc: 0.8946 - val_loss: 0.3326 - val_acc: 0.8648
# Epoch 123/150
#  - 1s - loss: 0.2488 - acc: 0.8943 - val_loss: 0.2987 - val_acc: 0.8755
# Epoch 124/150
#  - 1s - loss: 0.2492 - acc: 0.8950 - val_loss: 0.2985 - val_acc: 0.8742
# Epoch 125/150
#  - 1s - loss: 0.2490 - acc: 0.8948 - val_loss: 0.3112 - val_acc: 0.8697
# Epoch 126/150
#  - 1s - loss: 0.2472 - acc: 0.8948 - val_loss: 0.2937 - val_acc: 0.8716
# Epoch 127/150
#  - 1s - loss: 0.2469 - acc: 0.8950 - val_loss: 0.3028 - val_acc: 0.8676
# Epoch 128/150
#  - 1s - loss: 0.2461 - acc: 0.8954 - val_loss: 0.3267 - val_acc: 0.8680
# Epoch 129/150
#  - 1s - loss: 0.2487 - acc: 0.8944 - val_loss: 0.2843 - val_acc: 0.8766
# Epoch 130/150
#  - 1s - loss: 0.2482 - acc: 0.8962 - val_loss: 0.2970 - val_acc: 0.8757
# Epoch 131/150
#  - 1s - loss: 0.2474 - acc: 0.8945 - val_loss: 0.2883 - val_acc: 0.8755
# Epoch 132/150
#  - 1s - loss: 0.2453 - acc: 0.8957 - val_loss: 0.3288 - val_acc: 0.8675
# Epoch 133/150
#  - 1s - loss: 0.2486 - acc: 0.8949 - val_loss: 0.3392 - val_acc: 0.8650
# Epoch 134/150
#  - 1s - loss: 0.2470 - acc: 0.8946 - val_loss: 0.2901 - val_acc: 0.8759
# Epoch 135/150
#  - 1s - loss: 0.2501 - acc: 0.8944 - val_loss: 0.3363 - val_acc: 0.8590
# Epoch 136/150
#  - 1s - loss: 0.2488 - acc: 0.8949 - val_loss: 0.3068 - val_acc: 0.8700
# Epoch 137/150
#  - 1s - loss: 0.2475 - acc: 0.8945 - val_loss: 0.3061 - val_acc: 0.8614
# Epoch 138/150
#  - 1s - loss: 0.2467 - acc: 0.8963 - val_loss: 0.2979 - val_acc: 0.8746
# Epoch 139/150
#  - 1s - loss: 0.2467 - acc: 0.8939 - val_loss: 0.3131 - val_acc: 0.8671
# Epoch 140/150
#  - 1s - loss: 0.2453 - acc: 0.8947 - val_loss: 0.3019 - val_acc: 0.8631
# Epoch 141/150
#  - 1s - loss: 0.2470 - acc: 0.8944 - val_loss: 0.2937 - val_acc: 0.8737
# Epoch 142/150
#  - 1s - loss: 0.2491 - acc: 0.8949 - val_loss: 0.2940 - val_acc: 0.8718
# Epoch 143/150
#  - 1s - loss: 0.2464 - acc: 0.8946 - val_loss: 0.2879 - val_acc: 0.8745
# Epoch 144/150
#  - 1s - loss: 0.2484 - acc: 0.8926 - val_loss: 0.3004 - val_acc: 0.8684
# Epoch 145/150
#  - 1s - loss: 0.2484 - acc: 0.8931 - val_loss: 0.2925 - val_acc: 0.8730
# Epoch 146/150
#  - 1s - loss: 0.2479 - acc: 0.8966 - val_loss: 0.3015 - val_acc: 0.8723
# Epoch 147/150
#  - 1s - loss: 0.2463 - acc: 0.8940 - val_loss: 0.3214 - val_acc: 0.8637
# Epoch 148/150
#  - 1s - loss: 0.2479 - acc: 0.8930 - val_loss: 0.2945 - val_acc: 0.8717
# Epoch 149/150
#  - 1s - loss: 0.2458 - acc: 0.8934 - val_loss: 0.2931 - val_acc: 0.8693
# Epoch 150/150
#  - 1s - loss: 0.2471 - acc: 0.8949 - val_loss: 0.3143 - val_acc: 0.8717
#
#
# acc: 87.17%
